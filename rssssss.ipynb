# %% [markdown]
# <a href="https://colab.research.google.com/github/SlotSun/Recommender-System-Pytorch/blob/main/rssssss.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pwd
# Out:
# /content

# %%
cd sample_data/
# Out:
# /content/sample_data

# %%
# !ls
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
# !git clone https://github.com/QikaiXu/Recommender-System-Pytorch.git
# Out:
# Cloning into 'Recommender-System-Pytorch'...
# remote: Enumerating objects: 67, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 67 (delta 17), reused 62 (delta 12), pack-reused 0
# Unpacking objects: 100% (67/67), done.

# %%
# %run AFM.ipynb
# Out:
# Training on [cuda:0].
# CPU times: user 1.12 ms, sys: 0 ns, total: 1.12 ms
# Wall time: 1.67 ms
# CPU times: user 6.79 s, sys: 1.81 s, total: 8.6 s
# Wall time: 13.2 s
#  50%|████▉     | 298/600 [03:17<03:20,  1.51it/s]
# train_loss: 0.34865 | train_metric: 0.90236
# valid_loss: 0.46359 | valid_metric: 0.75728
# test_loss:  0.44878 | test_auc:  0.76541
# CPU times: user 3min 16s, sys: 700 ms, total: 3min 17s
# Wall time: 3min 17s

# %%
# !/opt/bin/nvidia-smi
# Out:
# Sat Jan 15 08:56:15 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   57C    P0    28W /  70W |   8224MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
cd notebook/
# Out:
# /content/sample_data/Recommender-System-Pytorch/notebook

# %%
# %run NeuralCF.ipynb
# Out:
# Training on [cuda:0].
# CPU times: user 178 µs, sys: 4 µs, total: 182 µs
# Wall time: 187 µs
# CPU times: user 814 ms, sys: 36.2 ms, total: 851 ms
# Wall time: 850 ms
#  18%|█▊        | 107/600 [00:08<00:41, 12.00it/s]
# train_loss: 0.45497 | train_metric: 0.85914
# valid_loss: 0.53361 | valid_metric: 0.78745
# test_loss:  0.53142 | test_metric:  0.79571
# CPU times: user 8.95 s, sys: 187 ms, total: 9.13 s
# Wall time: 9.17 s

# %%
# %run PNN.ipynb
# Out:
# Training on [cuda:0].
# CPU times: user 687 µs, sys: 0 ns, total: 687 µs
# Wall time: 693 µs
# CPU times: user 3.9 s, sys: 159 ms, total: 4.06 s
# Wall time: 4.04 s
#  17%|█▋        | 103/600 [00:42<03:27,  2.40it/s]
# train_loss: 0.50775 | train_metric: 0.87520
# valid_loss: 0.53945 | valid_metric: 0.74701
# test_loss:  0.53309 | test_auc:  0.75162
# CPU times: user 43 s, sys: 231 ms, total: 43.2 s
# Wall time: 43.3 s
#  17%|█▋        | 103/600 [00:09<00:45, 10.92it/s]
# train_loss: 0.55318 | train_metric: 0.89795
# valid_loss: 0.58662 | valid_metric: 0.74933
# test_loss:  0.58180 | test_auc:  0.76082
# CPU times: user 9.43 s, sys: 161 ms, total: 9.59 s
# Wall time: 9.68 s

# %%
# %run LFM.ipynb
# Out:
# Training on [cuda:0].
# CPU times: user 700 µs, sys: 12 µs, total: 712 µs
# Wall time: 620 µs
# CPU times: user 841 ms, sys: 5.92 ms, total: 847 ms
# Wall time: 846 ms
#  21%|██        | 126/600 [00:05<00:19, 24.30it/s]
# train_loss: 0.68837 | train_metric: 0.81204
# valid_loss: 0.68935 | valid_metric: 0.73177
# test_loss:  0.68940 | test_metric:  0.73959
# CPU times: user 5.27 s, sys: 118 ms, total: 5.39 s
# Wall time: 5.41 s

# %%
# %run FNN.ipynb
# Out:
# Training on [cuda:0].
# CPU times: user 150 µs, sys: 0 ns, total: 150 µs
# Wall time: 154 µs
# CPU times: user 4.01 s, sys: 111 ms, total: 4.12 s
# Wall time: 4.11 s
#  24%|██▎       | 142/600 [00:12<00:41, 10.93it/s]
# train_loss: 0.35161 | train_metric: 0.90869
# valid_loss: 0.47893 | valid_metric: 0.74842
# test_loss:  0.46737 | test_auc:  0.75775
# CPU times: user 13 s, sys: 181 ms, total: 13.2 s
# Wall time: 13.2 s
#  17%|█▋        | 103/600 [00:10<00:51,  9.60it/s]
# train_loss: 0.49843 | train_metric: 0.93818
# valid_loss: 0.63006 | valid_metric: 0.72397
# test_loss:  0.62824 | test_auc:  0.73262
# CPU times: user 10.8 s, sys: 177 ms, total: 10.9 s
# Wall time: 11 s
